# %% [markdown]
# # 1. IMPORTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 2. LOAD DATASET

# %%
import kagglehub
path = kagglehub.dataset_download("blastchar/telco-customer-churn")

# %%
# Files in this dataset
os.listdir(path)

# %%
fp = os.path.join(path, 'WA_Fn-UseC_-Telco-Customer-Churn.csv')
df = pd.read_csv(fp)

# %%
df.head()

# %% [markdown]
# # 3. BASIC STRUCTURE CHECKS

# %%
df.shape

# %%
df.columns.tolist()

# %%
df.dtypes

# %%
df.info()

# %% [markdown]
# # 4. SUMMARY STATS

# %%
df.describe()

# %%
df.describe(include='all').T

# %% [markdown]
# # 5. MISSING VALUES OVERVIEW

# %%
missing = df.isna().sum().to_frame("missing_count")

# %%
missing["misssing_pct"] = (missing["missing_count"] / len(df)) * 100

# %%
missing

# %% [markdown]
# # 6. DUPLICATES CHECK

# %%
duplicates = df.duplicated().sum()

# %%
print("Duplicate rows:", duplicates)

# %% [markdown]
# # 7. UNIQUE VALUES PER COLUMN

# %%
unique_vals = df.nunique().to_frame("unique_count")

# %%
unique_vals

# %% [markdown]
# # 8. QUICK NUMERIC DISTRIBUTIONS (sanity check)

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
numeric_cols

# %%
df[numeric_cols].hist(figsize=(12, 10))
plt.tight_layout()
# plt.show() # "inline backend" feature: No explicit call to show() needed
